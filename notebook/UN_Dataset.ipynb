# %%
#Question 3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Question 4
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head(2)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2021  1517.016266              NaN
# 1     Afghanistan  2020  1968.341002              NaN

# %%
gdp_df.tail(2)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7660        Zimbabwe  1991  2781.787843              NaN
# 7661        Zimbabwe  1990  2704.757299              NaN

# %%
#Question 5
gdp_df.shape
# Out:
# (7662, 4)

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
#Question 6
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
gdp_df.rename(columns={'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2021     1517.016266
# 1     Afghanistan  2020     1968.341002
# 2     Afghanistan  2019     2079.921861
# 3     Afghanistan  2018     2060.698973
# 4     Afghanistan  2017     2096.093111
# ...           ...   ...             ...
# 7657     Zimbabwe  1994     2670.106615
# 7658     Zimbabwe  1993     2458.783255
# 7659     Zimbabwe  1992     2468.278257
# 7660     Zimbabwe  1991     2781.787843
# 7661     Zimbabwe  1990     2704.757299
#
# [7662 rows x 3 columns]

# %%
gdp_df.describe()
# Out:
#               Year          Value
# count  7662.000000    7662.000000
# mean   2006.388280   17206.979219
# std       9.418727   19363.258695
# min    1990.000000     436.376416
# 25%    1998.000000    3655.268993
# 50%    2007.000000   10132.449293
# 75%    2015.000000   24119.515045
# max    2022.000000  157602.482546

# %%
#Question 8
gdp_df['Year'] = 2000

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2000  1517.016266
# 1     Afghanistan  2000  1968.341002
# 2     Afghanistan  2000  2079.921861
# 3     Afghanistan  2000  2060.698973
# 4     Afghanistan  2000  2096.093111
# 5     Afghanistan  2000  2101.422187
# 6     Afghanistan  2000  2108.714173
# 7     Afghanistan  2000  2144.449634
# 8     Afghanistan  2000  2165.340915
# 9     Afghanistan  2000  2122.830759

# %%
gdp_df['Value'].hist();

# %%
sns.boxplot(data = gdp_df, x = 'Value');

# %%
#Question 9
gdp_df['Value'].median()
# Out:
# 10132.449293179425

# %%
gdp_df['Year'] = 1990 or 2000 or 2010 or 2020

# %%
gdp_df.head(2)
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  1990  1517.016266
# 1     Afghanistan  1990  1968.341002

# %%
#Question 10
sns.boxplot(data = gdp_df, x = 'Value');

# %%
sns.barplot(data = gdp_df);

# %%
sns.scatterplot(data = gdp_df);

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head(100)
# Out:
#    Country or Area  Year         Value  Value Footnotes
# 0      Afghanistan  2021   1517.016266              NaN
# 1      Afghanistan  2020   1968.341002              NaN
# 2      Afghanistan  2019   2079.921861              NaN
# 3      Afghanistan  2018   2060.698973              NaN
# 4      Afghanistan  2017   2096.093111              NaN
# ..             ...   ...           ...              ...
# 95         Albania  2013  11361.252492              NaN
# 96         Albania  2012  11227.950407              NaN
# 97         Albania  2011  11052.777935              NaN
# 98         Albania  2010  10749.466426              NaN
# 99         Albania  2009  10313.901711              NaN
#
# [100 rows x 4 columns]

# %%
gdp_df['Year'].min
# Out:
# <bound method Series.min of 0       2021
# 1       2020
# 2       2019
# 3       2018
# 4       2017
#         ...
# 7657    1994
# 7658    1993
# 7659    1992
# 7660    1991
# 7661    1990
# Name: Year, Length: 7662, dtype: int64>

# %%
gdp_df['Year'] = 1990

# %%
gdp_df['Value'].max
# Out:
# <bound method Series.max of 0       1517.016266
# 1       1968.341002
# 2       2079.921861
# 3       2060.698973
# 4       2096.093111
#            ...
# 7657    2670.106615
# 7658    2458.783255
# 7659    2468.278257
# 7660    2781.787843
# 7661    2704.757299
# Name: Value, Length: 7662, dtype: float64>

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')
